# %% [markdown]
# # **1️⃣ Import Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **2️⃣ Load Dataset**

# %%
# 📂 Load raw dataset
df = pd.read_csv('/content/Coffee Shop Sales.xlsx - Transactions.csv')

# Preview dataset
df.sample(7)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 81340            81514         5/2/2023          8:27:32                2
# 145051          145388        6/27/2023          9:42:29                1
# 24084            24141        2/12/2023         17:54:13                2
# 15814            15844        1/28/2023         16:46:28                1
# 112883          113145        5/31/2023          7:40:27                3
# 119151          119413         6/5/2023         16:36:49                2
# 31606            31663        2/25/2023         10:49:55                1
#
#         store_id   store_location  product_id  unit_price    product_category  \
# 81340          5  Lower Manhattan          46        2.50                 Tea
# 145051         5  Lower Manhattan          58        3.50  Drinking Chocolate
# 24084          3          Astoria          32        3.00              Coffee
# 15814          3          Astoria          76        3.50              Bakery
# 112883         5  Lower Manhattan          56        2.55                 Tea
# 119151         5  Lower Manhattan          43        3.00                 Tea
# 31606          3          Astoria          77        3.00              Bakery
#
#                  product_type            product_detail
# 81340        Brewed Green tea     Serenity Green Tea Rg
# 145051          Hot chocolate         Dark chocolate Rg
# 24084   Gourmet brewed coffee               Ethiopia Rg
# 15814                Biscotti   Chocolate Chip Biscotti
# 112883        Brewed Chai tea  Spicy Eye Opener Chai Rg
# 119151      Brewed herbal tea            Lemon Grass Lg
# 31606                   Scone             Oatmeal Scone

# %% [markdown]
# # **3️⃣ Explore Dataset**

# %%
# Shape of dataset
df.shape
# Out:
# (149116, 11)

# %%
# 🔍 Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  object
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 12.5+ MB

# %%
# 📊 Statistical Summary
df.describe()
# Out:
#        transaction_id  transaction_qty       store_id     product_id  \
# count   149116.000000    149116.000000  149116.000000  149116.000000
# mean     74737.371872         1.438276       5.342063      47.918607
# std      43153.600016         0.542509       2.074241      17.930020
# min          1.000000         1.000000       3.000000       1.000000
# 25%      37335.750000         1.000000       3.000000      33.000000
# 50%      74727.500000         1.000000       5.000000      47.000000
# 75%     112094.250000         2.000000       8.000000      60.000000
# max     149456.000000         8.000000       8.000000      87.000000
#
#           unit_price
# count  149116.000000
# mean        3.382219
# std         2.658723
# min         0.800000
# 25%         2.500000
# 50%         3.000000
# 75%         3.750000
# max        45.000000

# %%
# 🧩 Check Missing Values
df.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# dtype: int64

# %% [markdown]
# # **4️⃣ Data Cleaning & Transformation**

# %%
# ✏️ Rename Columns for Readability
df = df.rename(columns={
    'transaction_id'   : 'Order_id',
    'transaction_qty'  : 'Quantity',
    'transaction_date' : 'Order_date',
    'transaction_time' : 'Time'
})

# %%
# ➕ Add Total_Price Column
df['Total_Price'] = df['Quantity'] * df['unit_price']

# %%
# 🗑️ Drop Unnecessary Columns
df = df.drop(['store_id', 'product_id', 'product_detail'], axis=1)

# %%
# 🧹 Drop Missing Values
df = df.dropna()

# %%
# 📆 Convert Order_date to DateTime
df['Order_date'] = pd.to_datetime(df['Order_date'], errors='coerce')

# %% [markdown]
# ## **5️⃣ Standardize Text Columns**

# %%
# 🎨 Standardize string formatting
df['store_location']   = df['store_location'].str.strip().str.title()
df['product_category'] = df['product_category'].str.strip().str.title()
df['product_type']     = df['product_type'].str.strip().str.title()

# %% [markdown]
# # **6️⃣ Validate Cleaned Data**

# %%
# ✅ Quick sanity check
print("Final Shape:", df.shape)
print("Null Values:\n", df.isnull().sum())
df.head()
# Out:
# Final Shape: (149116, 9)
# Null Values:
#  Order_id            0
# Order_date          0
# Time                0
# Quantity            0
# store_location      0
# unit_price          0
# product_category    0
# product_type        0
# Total_Price         0
# dtype: int64
#    Order_id Order_date     Time  Quantity   store_location  unit_price  \
# 0         1 2023-01-01  7:06:11         2  Lower Manhattan         3.0
# 1         2 2023-01-01  7:08:56         2  Lower Manhattan         3.1
# 2         3 2023-01-01  7:14:04         2  Lower Manhattan         4.5
# 3         4 2023-01-01  7:20:24         1  Lower Manhattan         2.0
# 4         5 2023-01-01  7:22:41         2  Lower Manhattan         3.1
#
#      product_category           product_type  Total_Price
# 0              Coffee  Gourmet Brewed Coffee          6.0
# 1                 Tea        Brewed Chai Tea          6.2
# 2  Drinking Chocolate          Hot Chocolate          9.0
# 3              Coffee            Drip Coffee          2.0
# 4                 Tea        Brewed Chai Tea          6.2

# %% [markdown]
# # **7️⃣  Save Cleaned Dataset**

# %%
# 💾 Save cleaned dataset
df.to_csv('Cleaned_Coffee_Sales_Dataset.csv', index=False)

print("✅ Data cleaning complete! Cleaned file saved as 'Cleaned_Coffee_Sales_Dataset.csv'")
# Out:
# ✅ Data cleaning complete! Cleaned file saved as 'Cleaned_Coffee_Sales_Dataset.csv'
